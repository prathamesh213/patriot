# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_Facebook.csv',delimiter=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
subset1 = df[["like","share"]]
subset1
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
subset2 = df[["Category","Lifetime Engaged Users"]]
subset2
# Out:
#      Category  Lifetime Engaged Users
# 0           2                     178
# 1           2                    1457
# 2           3                     177
# 3           2                    2211
# 4           2                     671
# ..        ...                     ...
# 495         3                     733
# 496         2                     537
# 497         1                     625
# 498         3                     626
# 499         2                     564
#
# [500 rows x 2 columns]

# %%
mergeset = pd.merge(subset1, subset2, left_on = 'like',right_on = 'Lifetime Engaged Users')
mergeset
# Out:
#      like  share  Category  Lifetime Engaged Users
# 0   130.0   29.0         3                     130
# 1   130.0   31.0         3                     130
# 2    66.0   14.0         1                      66
# 3    66.0   14.0         1                      66
# 4    66.0   12.0         1                      66
# ..    ...    ...       ...                     ...
# 90  200.0   37.0         2                     200
# 91  579.0   47.0         3                     579
# 92  360.0   99.0         1                     360
# 93  360.0   99.0         1                     360
# 94  277.0   80.0         3                     277
#
# [95 rows x 4 columns]

# %%
mergeset.sort_values(by=['like'],ascending=False)
# Out:
#      like  share  Category  Lifetime Engaged Users
# 15  678.0   20.0         2                     678
# 85  664.0   97.0         3                     664
# 91  579.0   47.0         3                     579
# 13  577.0   20.0         3                     577
# 14  577.0   20.0         1                     577
# ..    ...    ...       ...                     ...
# 35   15.0    2.0         1                      15
# 38   15.0    1.0         1                      15
# 37   15.0    3.0         1                      15
# 36   15.0    1.0         1                      15
# 42    9.0    1.0         1                       9
#
# [95 rows x 4 columns]

# %%
mergeset.transpose
# Out:
# <bound method DataFrame.transpose of      like  share  Category  Lifetime Engaged Users
# 0   130.0   29.0         3                     130
# 1   130.0   31.0         3                     130
# 2    66.0   14.0         1                      66
# 3    66.0   14.0         1                      66
# 4    66.0   12.0         1                      66
# ..    ...    ...       ...                     ...
# 90  200.0   37.0         2                     200
# 91  579.0   47.0         3                     579
# 92  360.0   99.0         1                     360
# 93  360.0   99.0         1                     360
# 94  277.0   80.0         3                     277
#
# [95 rows x 4 columns]>

# %%
df.shape
# Out:
# (500, 19)

# %%
reshapeset = pd.melt(df, id_vars =['Type'], value_vars =['comment'])
reshapeset
# Out:
#        Type variable  value
# 0     Photo  comment      4
# 1    Status  comment      5
# 2     Photo  comment      0
# 3     Photo  comment     58
# 4     Photo  comment     19
# ..      ...      ...    ...
# 495   Photo  comment      5
# 496   Photo  comment      0
# 497   Photo  comment      4
# 498   Photo  comment      7
# 499   Photo  comment      0
#
# [500 rows x 3 columns]

# %%
reshapeset.shape
# Out:
# (500, 3)

# %%
df.transpose
# Out:
# <bound method DataFrame.transpose of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...
